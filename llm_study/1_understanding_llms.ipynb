# %% [markdown]
# # 1. Understanding LLMs

# %% [markdown]
# LLMs are trained on vast quantities of text data. This large-scale training allows LLMs to capture deeper contextual information and subtleties of human language compared to previous approaches. As a result, LLMs have significantly improved performance in a wide range of NLP tasks, including text translation, sentiment analysis, question answer- ing, and many more.
#
# The success of LLMs can be attributed to the **transformer architecture**

# %% [markdown]
# ## What is an LLM?

# %% [markdown]
# <div>
# <img src="image.png" width="500"/>
# </div>
#
# The **“large” in “large language model”** refers to both the model’s size in terms of parameters and the immense dataset on which it’s trained.

# %% [markdown]
# ## Stages of Building & Using an LLM

# %% [markdown]
# We can divide the process of creating an LLM into **pre-training** and **fine-tuning**.
# >
# > **Pretraining**: Training the model on a large, diverse dataset for it to develop a broad understanding of language
# > - This is how you create a *base* or *foundation* model
# > - The base model has capability: text completion + few-shot capabilities (learn new tasks based on few examples)
# >
# > **Fine-tuning**: Training a model on a narrower dataset particular to certain domains
# > - **Instruction-finetuning**: The labeled dataset consists of instruction and answer pairs, such as a query to translate a text accompanied by the correctly translated text.
# > - **Classification-finetuning**: The labeled dataset consists of texts and associated class labels - for example, emails associated with “spam ” and “not spam” labels.

# %% [markdown]
# <div>
# <img src="train_stages.png" width="500"/>
# </div>

# %% [markdown]
# ## Transformers

# %% [markdown]
# The transformer was first invented to translate English to German and French :D
#
# A transformer has an **encoder** and **decoder**.
#
# The **encoder** module: processes input text & encodes it into series of numerical representations/vectors that capture contextual information in text
#
# The **decoder** module: takes encoded vectors and generates the output text.
#
# e.g. in translation:
# - encoder encodes text from source language into vectors
# - decoder decodes these vectors into target language
#
# both the encoder and decoder consist of many layers connected by self-attention!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >**Example:** BERT and its variants specialize in masked word prediction (so it's good at text classification, sentiment prediction, document categorization)

# %% [markdown]
# **GPT** focuses on the decoder portion of the original transformer architecture & is designed for generating text (from zero-shot and few-shot examples)

# %% [markdown]
# ## A Closer Look at the GPT Architecture

# %% [markdown]
# GPT was originally introduced in the paper “Improving Language Understanding by Generative Pre-Training” (https://mng.bz/x2qg) by Radford et al. from OpenAI. GPT-3 is a scaled-up version of this model that has more parameters and was trained on a larger dataset.
#
# In addition, the original model offered in ChatGPT was created by fine-tuning GPT-3 on a large instruction dataset using a method from OpenAI’s InstructGPT paper (https://arxiv.org/abs/2203.02155).

# %% [markdown]
# The next-word prediction task is a form of **self-supervised learning**, which is a form of **self-labeling**. This means that we don’t need to collect labels for the training data explicitly but can use the structure of the data itself: **we can use the next word in a sentence or document as the label** that the model is supposed to predict. Since this next- word prediction task allows us to create labels “on the fly,” it is possible to use massive unlabeled text datasets to train LLMs.

# %% [markdown]
# Since decoder-style models like GPT generate text by predicting text one word at a time, they are considered a type of autoregressive model. A**utoregressive models incorporate their previous outputs as inputs for future predictions.** Consequently, in GPT, each new word is chosen based on the sequence that precedes it, which improves the coherence of the resulting text.

# %% [markdown]
# ![image.png](attachment:image.png)
